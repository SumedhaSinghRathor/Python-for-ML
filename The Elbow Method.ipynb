# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

plt.rcParams['figure.figsize'] = (16, 9)

X, Y = make_blobs(n_samples=800, n_features=3, centers=4)

# %%
X
# Out:
# array([[ -9.24995102,   6.4984589 ,  -3.96035289],
#        [-10.8296976 ,   6.94794931,  -1.21368442],
#        [  7.30568052,  10.89560038,  -0.70268866],
#        ...,
#        [  3.19501922,   8.43381829,  -5.46470425],
#        [  1.37370775,   7.71273875,  -4.61498126],
#        [  2.41198252,  -0.05923504,   0.71103949]])

# %%
#finding the optimal number of clusters using elbow method
wcss_list = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X)
    wcss_list.append(kmeans.inertia_)

# %%
plt.plot(range(1,11), wcss_list)
plt.title('the elbow method')
plt.xlabel('number of clusters')
plt.ylabel('wcss_list')
# Out:
# Text(0, 0.5, 'wcss_list')
