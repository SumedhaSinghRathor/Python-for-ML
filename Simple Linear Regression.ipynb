# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("homeprices.csv")
df
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel('area(sq ft)')
plt.ylabel('price($)')
plt.scatter(df.Area, df.Price, color = 'red', marker='+')

# %%
reg = LinearRegression()
reg.fit(df[['Area']], df.Price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# C:\Users\KIIT\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
#printing the value of the m coefficient
reg.coef_
# Out:
# array([135.78767123])

# %%
#printing the value of the y intercept
reg.intercept_
# Out:
# 180616.43835616432
